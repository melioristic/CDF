# %%
import matplotlib.pyplot as plt
from cdf.io import YearWiseData

# %%
ds_path = "/data/compoundx/WeatherBench/"
var_name = "geopotential_500"

data = YearWiseData(ds_path=ds_path, folder_name=var_name)

# %%
plt.imshow(data[1])
plt.show()
